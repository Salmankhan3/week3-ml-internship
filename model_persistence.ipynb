# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X = np.linspace(-3, 3, 40)
y = np.sin(X) + np.random.normal(scale=0.3, size=len(X))

# %%
plt.scatter(X,y,color='red')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
poly_feature=PolynomialFeatures(degree=3)
poly_x=poly_feature.fit_transform(X.reshape(-1,1))

# %%
model=LinearRegression()
model.fit(poly_x,y)
# Out:
# LinearRegression()

# %%
coeff=model.coef_
intercept=model.intercept_
print(f"model coefficient : {coeff}")
print(f"model intercept : {intercept}")
# Out:
# model coefficient : [ 0.          0.90215623  0.01830644 -0.1090556 ]
# model intercept : -0.12332674061632294

# %% [markdown]
# ## Saving Model and model weights

# %%
import pickle

# %%
pickle.dump(model,open("polynomial_model.pkl",'wb'))

# %%
import joblib

# %%
joblib.dump(model,"polynomial_model.joblib")
# Out:
# ['polynomial_model.joblib']

# %%
import json

# %%
model_weight={
    "coeff":model.coef_.tolist(),
    "intercept":model.intercept_
}

# %%
with open("model_weight.json" ,'w') as file:
    json.dump(model_weight,file)
